# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('data_car.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
# to find the shape of the data test
df.shape
# Out:
# (11914, 16)

# %%
# summery of dataset 
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %%
# information of the data set 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
# Total number of of Duplicates present in data
display("Total number of of Duplicates present in data: %s" %df.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 715'

# %%
# dropping the duplicates rows
df.drop_duplicates(inplace=True)
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11199 rows x 16 columns]

# %%
#Total number of of Duplicates present in data
display("Total number of of Duplicates present in data: %s" %df.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 0'

# %%
df=df.reset_index(drop=True)
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11194    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11195    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11196    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11197    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11198  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11194               6.0         AUTOMATIC    all wheel drive              4.0
# 11195               6.0         AUTOMATIC    all wheel drive              4.0
# 11196               6.0         AUTOMATIC    all wheel drive              4.0
# 11197               6.0         AUTOMATIC    all wheel drive              4.0
# 11198               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11194             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11195             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11196             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11197             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11198                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11194           23        16         204  46120
# 11195           23        16         204  56670
# 11196           23        16         204  50620
# 11197           23        16         204  50920
# 11198           26        17          61  28995
#
# [11199 rows x 16 columns]

# %%
## To check the missing values

# %%
print("Number of Missing Values in our data set\n")
missing_df = df.isnull().sum().to_frame().reset_index().rename({"index" : 'Variable', 0: 'Missing Values'}, axis =1)
display(missing_df.style.background_gradient('gnuplot2_r'))
print("\n Percentage of Missing Values in our data set")
display((df.isnull().sum() / (len(df.index)) * 100).head(20).to_frame().rename({0:'Count'}, axis = 1).style.background_gradient('gnuplot2_r'))
round((df.isnull().sum() / (len(df.index)) * 100) , 2).plot(kind = 'barh',color ='maroon')

plt.title("Percentage of Missing values");
# Out:
# Number of Missing Values in our data set
# <style type="text/css">
# #T_221e9_row0_col1, #T_221e9_row1_col1, #T_221e9_row2_col1, #T_221e9_row3_col1, #T_221e9_row6_col1, #T_221e9_row7_col1, #T_221e9_row8_col1, #T_221e9_row10_col1, #T_221e9_row11_col1, #T_221e9_row12_col1, #T_221e9_row13_col1, #T_221e9_row14_col1, #T_221e9_row15_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_221e9_row4_col1 {
#   background-color: #ffffc0;
#   color: #000000;
# }
# #T_221e9_row5_col1 {
#   background-color: #ffffe6;
#   color: #000000;
# }
# #T_221e9_row9_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_221e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_221e9_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_221e9_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_221e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_221e9_row0_col0" class="data row0 col0" >Make</td>
#       <td id="T_221e9_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_221e9_row1_col0" class="data row1 col0" >Model</td>
#       <td id="T_221e9_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_221e9_row2_col0" class="data row2 col0" >Year</td>
#       <td id="T_221e9_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_221e9_row3_col0" class="data row3 col0" >Engine Fuel Type</td>
#       <td id="T_221e9_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_221e9_row4_col0" class="data row4 col0" >Engine HP</td>
#       <td id="T_221e9_row4_col1" class="data row4 col1" >69</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_221e9_row5_col0" class="data row5 col0" >Engine Cylinders</td>
#       <td id="T_221e9_row5_col1" class="data row5 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_221e9_row6_col0" class="data row6 col0" >Transmission Type</td>
#       <td id="T_221e9_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_221e9_row7_col0" class="data row7 col0" >Driven_Wheels</td>
#       <td id="T_221e9_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_221e9_row8_col0" class="data row8 col0" >Number of Doors</td>
#       <td id="T_221e9_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_221e9_row9_col0" class="data row9 col0" >Market Category</td>
#       <td id="T_221e9_row9_col1" class="data row9 col1" >3376</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_221e9_row10_col0" class="data row10 col0" >Vehicle Size</td>
#       <td id="T_221e9_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_221e9_row11_col0" class="data row11 col0" >Vehicle Style</td>
#       <td id="T_221e9_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_221e9_row12_col0" class="data row12 col0" >highway MPG</td>
#       <td id="T_221e9_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_221e9_row13_col0" class="data row13 col0" >city mpg</td>
#       <td id="T_221e9_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_221e9_row14_col0" class="data row14 col0" >Popularity</td>
#       <td id="T_221e9_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_221e9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_221e9_row15_col0" class="data row15 col0" >MSRP</td>
#       <td id="T_221e9_row15_col1" class="data row15 col1" >0</td>
#     </tr>
#   </tbody>
# </table>
#  Percentage of Missing Values in our data set
# <style type="text/css">
# #T_8cbb8_row0_col0, #T_8cbb8_row1_col0, #T_8cbb8_row2_col0, #T_8cbb8_row3_col0, #T_8cbb8_row6_col0, #T_8cbb8_row7_col0, #T_8cbb8_row8_col0, #T_8cbb8_row10_col0, #T_8cbb8_row11_col0, #T_8cbb8_row12_col0, #T_8cbb8_row13_col0, #T_8cbb8_row14_col0, #T_8cbb8_row15_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_8cbb8_row4_col0 {
#   background-color: #ffffc0;
#   color: #000000;
# }
# #T_8cbb8_row5_col0 {
#   background-color: #ffffe6;
#   color: #000000;
# }
# #T_8cbb8_row9_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8cbb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cbb8_level0_col0" class="col_heading level0 col0" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cbb8_level0_row0" class="row_heading level0 row0" >Make</th>
#       <td id="T_8cbb8_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row1" class="row_heading level0 row1" >Model</th>
#       <td id="T_8cbb8_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row2" class="row_heading level0 row2" >Year</th>
#       <td id="T_8cbb8_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row3" class="row_heading level0 row3" >Engine Fuel Type</th>
#       <td id="T_8cbb8_row3_col0" class="data row3 col0" >0.026788</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row4" class="row_heading level0 row4" >Engine HP</th>
#       <td id="T_8cbb8_row4_col0" class="data row4 col0" >0.616126</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row5" class="row_heading level0 row5" >Engine Cylinders</th>
#       <td id="T_8cbb8_row5_col0" class="data row5 col0" >0.267881</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row6" class="row_heading level0 row6" >Transmission Type</th>
#       <td id="T_8cbb8_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row7" class="row_heading level0 row7" >Driven_Wheels</th>
#       <td id="T_8cbb8_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row8" class="row_heading level0 row8" >Number of Doors</th>
#       <td id="T_8cbb8_row8_col0" class="data row8 col0" >0.053576</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row9" class="row_heading level0 row9" >Market Category</th>
#       <td id="T_8cbb8_row9_col0" class="data row9 col0" >30.145549</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row10" class="row_heading level0 row10" >Vehicle Size</th>
#       <td id="T_8cbb8_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row11" class="row_heading level0 row11" >Vehicle Style</th>
#       <td id="T_8cbb8_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row12" class="row_heading level0 row12" >highway MPG</th>
#       <td id="T_8cbb8_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row13" class="row_heading level0 row13" >city mpg</th>
#       <td id="T_8cbb8_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row14" class="row_heading level0 row14" >Popularity</th>
#       <td id="T_8cbb8_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb8_level0_row15" class="row_heading level0 row15" >MSRP</th>
#       <td id="T_8cbb8_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Treating Missing Values

# %%
#We will use Mode to fill up missing values in Categorical columns
df['Market Category'].fillna(df['Market Category'].mode()[0], inplace = True)
df['Engine Fuel Type'].fillna(df['Engine Fuel Type'].mode()[0], inplace = True)
   

#We will use mean to fill up missing values in Numerical Continuous columns
df['Engine HP'].fillna(df['Engine HP'].mean(), inplace = True)

#We will use median to fill up missing values in Ordinal Numerical Discrete columns
df['Engine Cylinders'].fillna(df['Engine Cylinders'].median(), inplace = True)
df['Number of Doors'].fillna(df['Number of Doors'].median(), inplace = True)

#Checking Missing Values after imputing
display(df.isnull().sum().to_frame().reset_index().rename({'index' : 'Variables', 0: 'Missing Values'}, axis =1).style.background_gradient('copper_r'))
# Out:
# <style type="text/css">
# #T_7208e_row0_col1, #T_7208e_row1_col1, #T_7208e_row2_col1, #T_7208e_row3_col1, #T_7208e_row4_col1, #T_7208e_row5_col1, #T_7208e_row6_col1, #T_7208e_row7_col1, #T_7208e_row8_col1, #T_7208e_row9_col1, #T_7208e_row10_col1, #T_7208e_row11_col1, #T_7208e_row12_col1, #T_7208e_row13_col1, #T_7208e_row14_col1, #T_7208e_row15_col1 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# </style>
# <table id="T_7208e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7208e_level0_col0" class="col_heading level0 col0" >Variables</th>
#       <th id="T_7208e_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7208e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7208e_row0_col0" class="data row0 col0" >Make</td>
#       <td id="T_7208e_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7208e_row1_col0" class="data row1 col0" >Model</td>
#       <td id="T_7208e_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7208e_row2_col0" class="data row2 col0" >Year</td>
#       <td id="T_7208e_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7208e_row3_col0" class="data row3 col0" >Engine Fuel Type</td>
#       <td id="T_7208e_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7208e_row4_col0" class="data row4 col0" >Engine HP</td>
#       <td id="T_7208e_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7208e_row5_col0" class="data row5 col0" >Engine Cylinders</td>
#       <td id="T_7208e_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7208e_row6_col0" class="data row6 col0" >Transmission Type</td>
#       <td id="T_7208e_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7208e_row7_col0" class="data row7 col0" >Driven_Wheels</td>
#       <td id="T_7208e_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7208e_row8_col0" class="data row8 col0" >Number of Doors</td>
#       <td id="T_7208e_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7208e_row9_col0" class="data row9 col0" >Market Category</td>
#       <td id="T_7208e_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7208e_row10_col0" class="data row10 col0" >Vehicle Size</td>
#       <td id="T_7208e_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7208e_row11_col0" class="data row11 col0" >Vehicle Style</td>
#       <td id="T_7208e_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7208e_row12_col0" class="data row12 col0" >highway MPG</td>
#       <td id="T_7208e_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7208e_row13_col0" class="data row13 col0" >city mpg</td>
#       <td id="T_7208e_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7208e_row14_col0" class="data row14 col0" >Popularity</td>
#       <td id="T_7208e_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7208e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7208e_row15_col0" class="data row15 col0" >MSRP</td>
#       <td id="T_7208e_row15_col1" class="data row15 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data Description and Initial Cleaning

# %%
df.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11199.000000  11199.000000      11199.000000     11199.000000
# mean    2010.714528    253.388859          5.666845         3.454416
# std        7.228211    109.811049          1.794696         0.872804
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    172.000000          4.000000         2.000000
# 50%     2015.000000    240.000000          6.000000         4.000000
# 75%     2016.000000    303.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11199.000000  11199.000000  11199.000000  1.119900e+04
# mean      26.610590     19.731851   1558.483347  4.192593e+04
# std        8.977641      9.177555   1445.668872  6.153505e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.159950e+04
# 50%       25.000000     18.000000   1385.000000  3.067500e+04
# 75%       30.000000     22.000000   2009.000000  4.303250e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %%
df.describe(include="object")
# Out:
#              Make           Model  Engine Fuel Type Transmission Type  \
# count       11199           11199             11199             11199
# unique         48             915                10                 5
# top     Chevrolet  Silverado 1500  regular unleaded         AUTOMATIC
# freq         1083             156              6661              7932
#
#             Driven_Wheels Market Category Vehicle Size Vehicle Style
# count               11199           11199        11199         11199
# unique                  4              71            3            16
# top     front wheel drive       Crossover      Compact         Sedan
# freq                 4354            4451         4395          2843

# %%
## Cleaning Strings in Columns Names

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
# Handling Categorical Data

# %%
categorical = list(df.dtypes[df.dtypes == 'object'].index)
categorical
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
# Cleaning Categorical Data in our data set

# %%
for col in categorical:
    df[col] = df[col].str.lower().str.replace(" ", "_")
    
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
# Unique values in Categorical Columns

# %%
for col in categorical:
    print(col)
    print(df[col].unique())
    print("Number of unique classes ",df[col].nunique())
    print('\n')
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler' 'nissan' 'volvo' 'mazda'
#  'mitsubishi' 'ferrari' 'alfa_romeo' 'toyota' 'mclaren' 'maybach'
#  'pontiac' 'porsche' 'saab' 'gmc' 'hyundai' 'plymouth' 'honda'
#  'oldsmobile' 'suzuki' 'ford' 'cadillac' 'kia' 'bentley' 'chevrolet'
#  'dodge' 'lamborghini' 'lincoln' 'subaru' 'volkswagen' 'spyker' 'buick'
#  'acura' 'rolls-royce' 'maserati' 'lexus' 'aston_martin' 'land_rover'
#  'lotus' 'infiniti' 'scion' 'genesis' 'hummer' 'tesla' 'bugatti']
# Number of unique classes  48
#
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class' '2_series' '200'
#  '200sx' '240sx' '240' '2' '3_series_gran_turismo' '3_series' '300-class'
#  '3000gt' '300' '300m' '300zx' '323' '350-class' '350z' '360' '370z' '3'
#  '4_series_gran_coupe' '4_series' '400-class' '420-class' '456m'
#  '458_italia' '4c' '4runner' '5_series_gran_turismo' '5_series'
#  '500-class' '500e' '500' '500l' '500x' '550' '560-class' '570s' '575m'
#  '57' '599' '5' '6_series_gran_coupe' '6_series' '600-class' '6000'
#  '612_scaglietti' '626' '62' '650s_coupe' '650s_spider' '6' '7_series'
#  '718_cayman' '740' '760' '780' '8_series' '80' '850' '86' '9-2x'
#  '9-3_griffin' '9-3' '9-4x' '9-5' '9-7x' '9000' '900' '90' '911' '928'
#  '929' '940' '944' '960' '968' 'a3' 'a4_allroad' 'a4' 'a5' 'a6' 'a7' 'a8'
#  'acadia_limited' 'acadia' 'accent' 'acclaim' 'accord_crosstour'
#  'accord_hybrid' 'accord_plug-in_hybrid' 'accord' 'achieva'
#  'activehybrid_5' 'activehybrid_7' 'activehybrid_x6' 'aerio' 'aerostar'
#  'alero' 'allante' 'allroad_quattro' 'allroad' 'alpina_b6_gran_coupe'
#  'alpina_b7' 'alpina' 'altima_hybrid' 'altima' 'amanti' 'amg_gt' 'armada'
#  'arnage' 'aspen' 'aspire' 'astro_cargo' 'astro' 'ats_coupe' 'ats-v' 'ats'
#  'aurora' 'avalanche' 'avalon_hybrid' 'avalon' 'avenger' 'aventador'
#  'aveo' 'aviator' 'axxess' 'azera' 'aztek' 'azure_t' 'azure'
#  'b-class_electric_drive' 'b-series_pickup' 'b-series_truck' 'b-series'
#  'b9_tribeca' 'baja' 'beetle_convertible' 'beetle' 'beretta'
#  'black_diamond_avalanche' 'blackwood' 'blazer' 'bolt_ev' 'bonneville'
#  'borrego' 'boxster' 'bravada' 'breeze' 'bronco_ii' 'bronco' 'brooklands'
#  'brougham' 'brz' 'c-class' 'c-max_hybrid' 'c30' 'c36_amg' 'c43_amg' 'c70'
#  'c8' 'cabriolet' 'cabrio' 'cadenza' 'caliber' 'california_t' 'california'
#  'camaro' 'camry_hybrid' 'camry_solara' 'camry' 'canyon' 'caprice'
#  'captiva_sport' 'caravan' 'carrera_gt' 'cascada' 'catera' 'cavalier'
#  'cayenne' 'cayman_s' 'cayman' 'cc' 'celebrity' 'celica' 'century'
#  'challenger' 'charger' 'chevy_van' 'ciera' 'cirrus' 'city_express'
#  'civic_crx' 'civic_del_sol' 'civic' 'c/k_1500_series' 'c/k_2500_series'
#  'cl-class' 'cla-class' 'cl' 'classic' 'clk-class' 'cls-class' 'cobalt'
#  'colorado' 'colt' 'concorde' 'continental_flying_spur_speed'
#  'continental_flying_spur' 'continental_gt_speed_convertible'
#  'continental_gt_speed' 'continental_gt3-r' 'continental_gt'
#  'continental_gtc_speed' 'continental_gtc'
#  'continental_supersports_convertible' 'continental_supersports'
#  'continental' 'contour_svt' 'contour' 'corniche' 'corolla_im' 'corolla'
#  'corrado' 'corsica' 'corvette_stingray' 'corvette' 'coupe' 'cr-v' 'cr-z'
#  'cressida' 'crossfire' 'crosstour' 'crosstrek' 'crown_victoria'
#  'cruze_limited' 'cruze' 'ct_200h' 'ct6' 'cts_coupe' 'cts-v_coupe'
#  'cts-v_wagon' 'cts-v' 'cts_wagon' 'cts' 'cube' 'custom_cruiser'
#  'cutlass_calais' 'cutlass_ciera' 'cutlass_supreme' 'cutlass' 'cx-3'
#  'cx-5' 'cx-7' 'cx-9' 'dakota' 'dart' 'dawn' 'daytona' 'db7' 'db9_gt'
#  'db9' 'dbs' 'defender' 'deville' 'diablo' 'diamante'
#  'discovery_series_ii' 'discovery_sport' 'discovery' 'dts' 'durango'
#  'dynasty' 'e-150' 'e-250' 'e-class' 'e-golf' 'e-series_van'
#  'e-series_wagon' 'e55_amg' 'echo' 'eclipse_spyder' 'eclipse' 'edge'
#  'eighty-eight_royale' 'eighty-eight' 'elantra_coupe' 'elantra_gt'
#  'elantra_touring' 'elantra' 'eldorado' 'electra' 'element' 'elise'
#  'enclave' 'encore' 'endeavor' 'entourage' 'envision' 'envoy_xl'
#  'envoy_xuv' 'envoy' 'enzo' 'eos' 'equator' 'equinox' 'equus' 'es_250'
#  'es_300h' 'es_300' 'es_330' 'es_350' 'escalade_esv' 'escalade_ext'
#  'escalade_hybrid' 'escalade' 'escape_hybrid' 'escape' 'escort' 'esprit'
#  'estate_wagon' 'esteem' 'eurovan' 'evora_400' 'evora' 'ex35' 'excel'
#  'exige' 'ex' 'expedition' 'explorer_sport_trac' 'explorer_sport'
#  'explorer' 'expo' 'express_cargo' 'express' 'f-150_heritage'
#  'f-150_svt_lightning' 'f-150' 'f-250' 'f12_berlinetta' 'f430' 'festiva'
#  'ff' 'fiesta' 'firebird' 'fit_ev' 'fit' 'five_hundred' 'fj_cruiser'
#  'fleetwood' 'flex' 'flying_spur' 'focus_rs' 'focus_st' 'focus' 'forenza'
#  'forester' 'forte' 'fox' 'fr-s' 'freelander' 'freestar' 'freestyle'
#  'frontier' 'fusion_hybrid' 'fusion' 'fx35' 'fx45' 'fx50' 'fx' 'g-class'
#  'g_convertible' 'g_coupe' 'g_sedan' 'g20' 'g35' 'g37_convertible'
#  'g37_coupe' 'g37_sedan' 'g37' 'g3' 'g5' 'g6' 'g80' 'g8' 'galant'
#  'gallardo' 'genesis_coupe' 'genesis' 'ghibli' 'ghost_series_ii' 'ghost'
#  'gl-class' 'gla-class' 'glc-class' 'gle-class_coupe' 'gle-class' 'gli'
#  'glk-class' 'gls-class' 'golf_alltrack' 'golf_gti' 'golf_r'
#  'golf_sportwagen' 'golf' 'grand_am' 'grand_caravan' 'grand_prix'
#  'grand_vitara' 'grand_voyager' 'gransport' 'granturismo_convertible'
#  'granturismo' 'gs_200t' 'gs_300' 'gs_350' 'gs_400' 'gs_430' 'gs_450h'
#  'gs_460' 'gs_f' 'gt-r' 'gt' 'gti' 'gto' 'gx_460' 'gx_470' 'h3' 'h3t'
#  'hhr' 'highlander_hybrid' 'highlander' 'horizon' 'hr-v' 'hs_250h'
#  'huracan' 'i-miev' 'i30' 'i35' 'i3' 'ia' 'ilx_hybrid' 'ilx'
#  'impala_limited' 'impala' 'imperial' 'impreza_wrx' 'impreza' 'im'
#  'insight' 'integra' 'intrepid' 'intrigue' 'iq' 'is_200t' 'is_250_c'
#  'is_250' 'is_300' 'is_350_c' 'is_350' 'is_f' 'j30' 'jetta_gli'
#  'jetta_hybrid' 'jetta_sportwagen' 'jetta' 'jimmy' 'journey' 'juke'
#  'justy' 'jx' 'k900' 'kizashi' 'lacrosse' 'lancer_evolution'
#  'lancer_sportback' 'lancer' 'land_cruiser' 'landaulet' 'laser' 'le_baron'
#  'le_mans' 'leaf' 'legacy' 'legend' 'lesabre' 'levante' 'lfa' 'lhs'
#  'loyale' 'lr2' 'lr3' 'lr4' 'ls_400' 'ls_430' 'ls_460' 'ls_600h_l' 'ls'
#  'lss' 'ltd_crown_victoria' 'lucerne' 'lumina_minivan' 'lumina' 'lx_450'
#  'lx_470' 'lx_570' 'm-class' 'm2' 'm30' 'm35' 'm37' 'm3' 'm4_gts' 'm45'
#  'm4' 'm56' 'm5' 'm6_gran_coupe' 'm6' 'macan' 'magnum' 'malibu_classic'
#  'malibu_hybrid' 'malibu_limited' 'malibu_maxx' 'malibu' 'mark_lt'
#  'mark_viii' 'mark_vii' 'matrix' 'maxima' 'maybach' 'mazdaspeed_3'
#  'mazdaspeed_6' 'mazdaspeed_mx-5_miata' 'mazdaspeed_protege' 'm' 'mdx'
#  'metris' 'metro' 'mighty_max_pickup' 'millenia' 'mirage_g4' 'mirage'
#  'mkc' 'mks' 'mkt' 'mkx' 'mkz_hybrid' 'mkz' 'ml55_amg' 'model_s' 'monaco'
#  'montana_sv6' 'montana' 'monte_carlo' 'montero_sport' 'montero' 'mp4-12c'
#  'mpv' 'mr2_spyder' 'mr2' 'mulsanne' 'murano_crosscabriolet' 'murano'
#  'murcielago' 'mustang_svt_cobra' 'mustang' 'mx-3' 'mx-5_miata' 'mx-6'
#  'navajo' 'navigator' 'neon' 'new_beetle' 'new_yorker' 'ninety-eight'
#  'nitro' 'nsx' 'nv200' 'nx_200t' 'nx_300h' 'nx' 'odyssey' 'omni'
#  'optima_hybrid' 'optima' 'outback' 'outlander_sport' 'outlander'
#  'pacifica' 'panamera' 'park_avenue' 'park_ward' 'paseo' 'passat'
#  'passport' 'pathfinder' 'phaeton' 'phantom_coupe'
#  'phantom_drophead_coupe' 'phantom' 'pickup' 'pilot' 'precis' 'prelude'
#  'previa' 'prius_c' 'prius_prime' 'prius_v' 'prius' 'prizm' 'probe'
#  'protege5' 'protege' 'prowler' 'pt_cruiser' 'pulsar' 'q3' 'q40' 'q45'
#  'q50' 'q5' 'q60_convertible' 'q60_coupe' 'q70' 'q7' 'quattroporte'
#  'quest' 'qx4' 'qx50' 'qx56' 'qx60' 'qx70' 'qx80' 'qx' 'r-class' 'r32'
#  'r8' 'rabbit' 'raider' 'rainier' 'rally_wagon' 'ram_150' 'ram_250'
#  'ram_50_pickup' 'ram_cargo' 'ram_pickup_1500' 'ram_van' 'ram_wagon'
#  'ramcharger' 'range_rover_evoque' 'range_rover_sport' 'range_rover'
#  'ranger' 'rapide_s' 'rapide' 'rav4_ev' 'rav4_hybrid' 'rav4' 'rc_200t'
#  'rc_300' 'rc_350' 'rc_f' 'rdx' 'reatta' 'regal' 'regency' 'rendezvous'
#  'reno' 'reventon' 'ridgeline' 'rio' 'riviera' 'rl' 'rlx' 'roadmaster'
#  'rogue_select' 'rogue' 'rondo' 'routan' 'rs_4' 'rs_5' 'rs_6' 'rs_7' 'rsx'
#  'rx_300' 'rx_330' 'rx_350' 'rx_400h' 'rx_450h' 'rx-7' 'rx-8'
#  's-10_blazer' 's-10' 's-15_jimmy' 's-15' 's-class' 's2000' 's3' 's40'
#  's4' 's5' 's60_cross_country' 's60' 's6' 's70' 's7' 's80' 's8' 's90'
#  'safari_cargo' 'safari' 'samurai' 'santa_fe_sport' 'santa_fe'
#  'savana_cargo' 'savana' 'sc_300' 'sc_400' 'sc_430' 'scoupe' 'sebring'
#  'sedona' 'sentra' 'sephia' 'sequoia' 'seville' 'shadow' 'shelby_gt350'
#  'shelby_gt500' 'sidekick' 'sienna' 'sierra_1500_classic'
#  'sierra_1500_hybrid' 'sierra_1500' 'sierra_1500hd' 'sierra_c3'
#  'sierra_classic_1500' 'sigma' 'silhouette' 'silver_seraph'
#  'silverado_1500_classic' 'silverado_1500_hybrid' 'silverado_1500'
#  'sixty_special' 'skylark' 'sl-class' 'slc-class' 'slk-class'
#  'slr_mclaren' 'sls_amg_gt_final_edition' 'sls_amg_gt' 'sls_amg' 'slx'
#  'solstice' 'sonata_hybrid' 'sonata' 'sonic' 'sonoma' 'sorento' 'soul_ev'
#  'soul' 'spark_ev' 'spark' 'spectra' 'spirit' 'sportage' 'sportvan'
#  'spyder' 'sq5' 'srt_viper' 'srx' 'ss' 'ssr' 'stanza' 'stealth' 'stratus'
#  'sts-v' 'sts' 'suburban' 'sunbird' 'sundance' 'sunfire' 'superamerica'
#  'supersports_convertible_isr' 'supra' 'svx' 'swift' 'sx4' 'syclone'
#  't100' 'tacoma' 'tahoe_hybrid' 'tahoe_limited/z71' 'tahoe' 'taurus_x'
#  'taurus' 'tc' 'tempo' 'tercel' 'terrain' 'terraza' 'thunderbird'
#  'tiburon' 'tiguan' 'titan' 'tl' 'tlx' 'toronado' 'torrent' 'touareg_2'
#  'touareg' 'town_and_country' 'town_car' 'tracker' 'trailblazer_ext'
#  'trailblazer' 'trans_sport' 'transit_connect' 'transit_wagon' 'traverse'
#  'trax' 'tribeca' 'tribute_hybrid' 'tribute' 'truck' 'tsx_sport_wagon'
#  'tsx' 'tt_rs' 'tt' 'tts' 'tucson' 'tundra' 'typhoon' 'uplander'
#  'v12_vanquish' 'v12_vantage_s' 'v12_vantage' 'v40' 'v50'
#  'v60_cross_country' 'v60' 'v70' 'v8_vantage' 'v8' 'v90' 'vanagon'
#  'vandura' 'van' 'vanquish' 'vanwagon' 'veloster' 'venture' 'venza'
#  'veracruz' 'verano' 'verona' 'versa_note' 'versa' 'veyron_16.4' 'vibe'
#  'vigor' 'viper' 'virage' 'vitara' 'voyager' 'windstar_cargo' 'windstar'
#  'wraith' 'wrx' 'x-90' 'x1' 'x3' 'x4' 'x5_m' 'x5' 'x6_m' 'x6' 'xa' 'xb'
#  'xc60' 'xc70' 'xc90' 'xc' 'xd' 'xg300' 'xg350' 'xl-7' 'xl7' 'xlr-v' 'xlr'
#  'xt5' 'xterra' 'xts' 'xt' 'xv_crosstrek' 'yaris_ia' 'yaris'
#  'yukon_denali' 'yukon_hybrid' 'yukon_xl' 'yukon' 'z3' 'z4_m' 'z4' 'z8'
#  'zdx' 'zephyr']
# Number of unique classes  914
#
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel'
#  'electric' 'flex-fuel_(premium_unleaded_recommended/e85)' 'natural_gas'
#  'flex-fuel_(premium_unleaded_required/e85)'
#  'flex-fuel_(unleaded/natural_gas)']
# Number of unique classes  10
#
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# Number of unique classes  5
#
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# Number of unique classes  4
#
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance' 'flex_fuel'
#  'flex_fuel,performance' 'crossover' 'hatchback'
#  'hatchback,luxury,performance' 'hatchback,luxury'
#  'luxury,high-performance,hybrid' 'diesel,luxury' 'hatchback,performance'
#  'hatchback,factory_tuner,performance' 'high-performance'
#  'factory_tuner,high-performance' 'exotic,high-performance'
#  'exotic,factory_tuner,high-performance' 'factory_tuner,performance'
#  'exotic,luxury' 'exotic,luxury,high-performance'
#  'exotic,luxury,performance' 'factory_tuner,luxury,performance'
#  'flex_fuel,luxury' 'crossover,luxury'
#  'hatchback,factory_tuner,luxury,performance' 'crossover,hatchback'
#  'hybrid' 'luxury,performance,hybrid'
#  'crossover,luxury,performance,hybrid' 'crossover,luxury,performance'
#  'exotic,factory_tuner,luxury,high-performance'
#  'flex_fuel,luxury,high-performance' 'crossover,flex_fuel' 'diesel'
#  'hatchback,diesel' 'crossover,luxury,diesel'
#  'crossover,luxury,high-performance'
#  'exotic,flex_fuel,factory_tuner,luxury,high-performance'
#  'exotic,flex_fuel,luxury,high-performance'
#  'exotic,factory_tuner,luxury,performance' 'hatchback,hybrid'
#  'crossover,hybrid' 'hatchback,luxury,hybrid'
#  'flex_fuel,luxury,performance' 'crossover,performance' 'luxury,hybrid'
#  'crossover,flex_fuel,luxury,performance' 'crossover,flex_fuel,luxury'
#  'crossover,flex_fuel,performance'
#  'hatchback,factory_tuner,high-performance' 'hatchback,flex_fuel'
#  'factory_tuner,luxury' 'crossover,factory_tuner,luxury,high-performance'
#  'crossover,factory_tuner,luxury,performance'
#  'crossover,hatchback,factory_tuner,performance'
#  'crossover,hatchback,performance' 'flex_fuel,hybrid'
#  'flex_fuel,performance,hybrid' 'crossover,exotic,luxury,high-performance'
#  'crossover,exotic,luxury,performance' 'exotic,performance'
#  'exotic,luxury,high-performance,hybrid' 'crossover,luxury,hybrid'
#  'flex_fuel,factory_tuner,luxury,high-performance' 'performance,hybrid'
#  'crossover,factory_tuner,performance' 'crossover,diesel'
#  'flex_fuel,diesel' 'crossover,hatchback,luxury']
# Number of unique classes  71
#
#
# vehicle_size
# ['compact' 'midsize' 'large']
# Number of unique classes  3
#
#
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback' '2dr_hatchback'
#  '4dr_suv' 'passenger_minivan' 'cargo_minivan' 'crew_cab_pickup'
#  'regular_cab_pickup' 'extended_cab_pickup' '2dr_suv' 'cargo_van'
#  'convertible_suv' 'passenger_van']
# Number of unique classes  16

# %%
# Removing Unusual Category from Transmission Type

# %%
df.drop(df.loc[df['transmission_type']=='unknown'].index, inplace=True)
df.shape
# Out:
# (11187, 16)

# %%
df.reset_index(drop=True)
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11182    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11183    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11184    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11185    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11186  lincoln      zephyr  2006                regular_unleaded      221.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0                   6.0            manual   rear_wheel_drive              2.0
# 1                   6.0            manual   rear_wheel_drive              2.0
# 2                   6.0            manual   rear_wheel_drive              2.0
# 3                   6.0            manual   rear_wheel_drive              2.0
# 4                   6.0            manual   rear_wheel_drive              2.0
# ...                 ...               ...                ...              ...
# 11182               6.0         automatic    all_wheel_drive              4.0
# 11183               6.0         automatic    all_wheel_drive              4.0
# 11184               6.0         automatic    all_wheel_drive              4.0
# 11185               6.0         automatic    all_wheel_drive              4.0
# 11186               6.0         automatic  front_wheel_drive              4.0
#
#                              market_category vehicle_size  vehicle_style  \
# 0      factory_tuner,luxury,high-performance      compact          coupe
# 1                         luxury,performance      compact    convertible
# 2                    luxury,high-performance      compact          coupe
# 3                         luxury,performance      compact          coupe
# 4                                     luxury      compact    convertible
# ...                                      ...          ...            ...
# 11182             crossover,hatchback,luxury      midsize  4dr_hatchback
# 11183             crossover,hatchback,luxury      midsize  4dr_hatchback
# 11184             crossover,hatchback,luxury      midsize  4dr_hatchback
# 11185             crossover,hatchback,luxury      midsize  4dr_hatchback
# 11186                                 luxury      midsize          sedan
#
#        highway_mpg  city_mpg  popularity   msrp
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11182           23        16         204  46120
# 11183           23        16         204  56670
# 11184           23        16         204  50620
# 11185           23        16         204  50920
# 11186           26        17          61  28995
#
# [11187 rows x 16 columns]

# %% [markdown]
# ## Handling Numerical Data

# %%
# Checking negative values in Numerical Columns

# %%
numerical = [col for col in df.columns if col not in categorical]
for i in numerical:
    df[df[i]<0]
    print("Records with Negative values in %s : " %i,df[df[i]<0])
    print('\n')
# Out:
# Records with Negative values in year :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in engine_hp :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in engine_cylinders :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in number_of_doors :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in highway_mpg :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in city_mpg :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in popularity :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in msrp :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []

# %%
numerical = [col for col in df.columns if col not in categorical]
for i in numerical:
   df[df[i]==0]
   print("Records with 0 values in %s : " %i,df[df[i]==0])
   print('\n')
# Out:
# Records with 0 values in year :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with 0 values in engine_hp :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with 0 values in engine_cylinders :                 make                   model  year engine_fuel_type  \
# 520            fiat                    500e  2015         electric
# 521            fiat                    500e  2016         electric
# 522            fiat                    500e  2017         electric
# 1642  mercedes-benz  b-class_electric_drive  2015         electric
# 1643  mercedes-benz  b-class_electric_drive  2016         electric
# 1644  mercedes-benz  b-class_electric_drive  2017         electric
# 4470          honda                  fit_ev  2013         electric
# 4471          honda                  fit_ev  2014         electric
# 4550           ford                   focus  2015         electric
# 4554           ford                   focus  2016         electric
# 4563           ford                   focus  2017         electric
# 5505            bmw                      i3  2015         electric
# 5506            bmw                      i3  2016         electric
# 5507            bmw                      i3  2017         electric
# 5508            bmw                      i3  2017         electric
# 6035         nissan                    leaf  2014         electric
# 6036         nissan                    leaf  2014         electric
# 6037         nissan                    leaf  2014         electric
# 6038         nissan                    leaf  2015         electric
# 6039         nissan                    leaf  2015         electric
# 6040         nissan                    leaf  2015         electric
# 6041         nissan                    leaf  2015         electric
# 6042         nissan                    leaf  2016         electric
# 6043         nissan                    leaf  2016         electric
# 6044         nissan                    leaf  2016         electric
# 6554          tesla                 model_s  2014         electric
# 6555          tesla                 model_s  2014         electric
# 6556          tesla                 model_s  2014         electric
# 6557          tesla                 model_s  2014         electric
# 6558          tesla                 model_s  2015         electric
# 6559          tesla                 model_s  2015         electric
# 6560          tesla                 model_s  2015         electric
# 6561          tesla                 model_s  2015         electric
# 6562          tesla                 model_s  2015         electric
# 6563          tesla                 model_s  2016         electric
# 6564          tesla                 model_s  2016         electric
# 6565          tesla                 model_s  2016         electric
# 6566          tesla                 model_s  2016         electric
# 6567          tesla                 model_s  2016         electric
# 6568          tesla                 model_s  2016         electric
# 6569          tesla                 model_s  2016         electric
# 6570          tesla                 model_s  2016         electric
# 6571          tesla                 model_s  2016         electric
# 7861         toyota                 rav4_ev  2013         electric
# 7862         toyota                 rav4_ev  2014         electric
# 9245            kia                 soul_ev  2015         electric
# 9246            kia                 soul_ev  2015         electric
# 9247            kia                 soul_ev  2016         electric
# 9248            kia                 soul_ev  2016         electric
# 9249            kia                 soul_ev  2016         electric
# 9262      chevrolet                spark_ev  2014         electric
# 9263      chevrolet                spark_ev  2014         electric
# 9264      chevrolet                spark_ev  2015         electric
# 9265      chevrolet                spark_ev  2015         electric
# 9266      chevrolet                spark_ev  2016         electric
# 9267      chevrolet                spark_ev  2016         electric
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 520   253.388859               0.0      direct_drive  front_wheel_drive
# 521   253.388859               0.0      direct_drive  front_wheel_drive
# 522   253.388859               0.0      direct_drive  front_wheel_drive
# 1642  177.000000               0.0      direct_drive  front_wheel_drive
# 1643  177.000000               0.0      direct_drive  front_wheel_drive
# 1644  177.000000               0.0      direct_drive  front_wheel_drive
# 4470  253.388859               0.0      direct_drive  front_wheel_drive
# 4471  253.388859               0.0      direct_drive  front_wheel_drive
# 4550  253.388859               0.0      direct_drive  front_wheel_drive
# 4554  253.388859               0.0      direct_drive  front_wheel_drive
# 4563  253.388859               0.0      direct_drive  front_wheel_drive
# 5505  170.000000               0.0      direct_drive   rear_wheel_drive
# 5506  170.000000               0.0      direct_drive   rear_wheel_drive
# 5507  170.000000               0.0      direct_drive   rear_wheel_drive
# 5508  170.000000               0.0      direct_drive   rear_wheel_drive
# 6035  253.388859               0.0      direct_drive  front_wheel_drive
# 6036  253.388859               0.0      direct_drive  front_wheel_drive
# 6037  253.388859               0.0      direct_drive  front_wheel_drive
# 6038  253.388859               0.0      direct_drive  front_wheel_drive
# 6039  253.388859               0.0      direct_drive  front_wheel_drive
# 6040  253.388859               0.0      direct_drive  front_wheel_drive
# 6041  253.388859               0.0      direct_drive  front_wheel_drive
# 6042  253.388859               0.0      direct_drive  front_wheel_drive
# 6043  253.388859               0.0      direct_drive  front_wheel_drive
# 6044  253.388859               0.0      direct_drive  front_wheel_drive
# 6554  253.388859               0.0      direct_drive   rear_wheel_drive
# 6555  253.388859               0.0      direct_drive   rear_wheel_drive
# 6556  253.388859               0.0      direct_drive    all_wheel_drive
# 6557  253.388859               0.0      direct_drive   rear_wheel_drive
# 6558  253.388859               0.0      direct_drive   rear_wheel_drive
# 6559  253.388859               0.0      direct_drive    all_wheel_drive
# 6560  253.388859               0.0      direct_drive    all_wheel_drive
# 6561  253.388859               0.0      direct_drive    all_wheel_drive
# 6562  253.388859               0.0      direct_drive   rear_wheel_drive
# 6563  253.388859               0.0      direct_drive    all_wheel_drive
# 6564  253.388859               0.0      direct_drive    all_wheel_drive
# 6565  253.388859               0.0      direct_drive    all_wheel_drive
# 6566  253.388859               0.0      direct_drive   rear_wheel_drive
# 6567  253.388859               0.0      direct_drive    all_wheel_drive
# 6568  253.388859               0.0      direct_drive    all_wheel_drive
# 6569  253.388859               0.0      direct_drive    all_wheel_drive
# 6570  253.388859               0.0      direct_drive    all_wheel_drive
# 6571  253.388859               0.0      direct_drive   rear_wheel_drive
# 7861  253.388859               0.0      direct_drive  front_wheel_drive
# 7862  253.388859               0.0      direct_drive  front_wheel_drive
# 9245  253.388859               0.0      direct_drive  front_wheel_drive
# 9246  253.388859               0.0      direct_drive  front_wheel_drive
# 9247  253.388859               0.0      direct_drive  front_wheel_drive
# 9248  253.388859               0.0      direct_drive  front_wheel_drive
# 9249  253.388859               0.0      direct_drive  front_wheel_drive
# 9262  140.000000               0.0      direct_drive  front_wheel_drive
# 9263  140.000000               0.0      direct_drive  front_wheel_drive
# 9264  140.000000               0.0      direct_drive  front_wheel_drive
# 9265  140.000000               0.0      direct_drive  front_wheel_drive
# 9266  140.000000               0.0      direct_drive  front_wheel_drive
# 9267  140.000000               0.0      direct_drive  front_wheel_drive
#
#       number_of_doors          market_category vehicle_size  vehicle_style  \
# 520               2.0                hatchback      compact  2dr_hatchback
# 521               2.0                hatchback      compact  2dr_hatchback
# 522               2.0                hatchback      compact  2dr_hatchback
# 1642              4.0         hatchback,luxury      compact  4dr_hatchback
# 1643              4.0         hatchback,luxury      compact  4dr_hatchback
# 1644              4.0         hatchback,luxury      compact  4dr_hatchback
# 4470              4.0                hatchback      compact  4dr_hatchback
# 4471              4.0                hatchback      compact  4dr_hatchback
# 4550              4.0                hatchback      compact  4dr_hatchback
# 4554              4.0                hatchback      compact  4dr_hatchback
# 4563              4.0                hatchback      compact  4dr_hatchback
# 5505              4.0         hatchback,luxury      compact  4dr_hatchback
# 5506              4.0         hatchback,luxury      compact  4dr_hatchback
# 5507              4.0         hatchback,luxury      compact  4dr_hatchback
# 5508              4.0         hatchback,luxury      compact  4dr_hatchback
# 6035              4.0                hatchback      compact  4dr_hatchback
# 6036              4.0                hatchback      compact  4dr_hatchback
# 6037              4.0                hatchback      compact  4dr_hatchback
# 6038              4.0                hatchback      compact  4dr_hatchback
# 6039              4.0                hatchback      compact  4dr_hatchback
# 6040              4.0                hatchback      compact  4dr_hatchback
# 6041              4.0                hatchback      compact  4dr_hatchback
# 6042              4.0                hatchback      compact  4dr_hatchback
# 6043              4.0                hatchback      compact  4dr_hatchback
# 6044              4.0                hatchback      compact  4dr_hatchback
# 6554              4.0  exotic,high-performance        large          sedan
# 6555              4.0       exotic,performance        large          sedan
# 6556              4.0  exotic,high-performance        large          sedan
# 6557              4.0  exotic,high-performance        large          sedan
# 6558              4.0       exotic,performance        large          sedan
# 6559              4.0       exotic,performance        large          sedan
# 6560              4.0  exotic,high-performance        large          sedan
# 6561              4.0  exotic,high-performance        large          sedan
# 6562              4.0       exotic,performance        large          sedan
# 6563              4.0       exotic,performance        large          sedan
# 6564              4.0       exotic,performance        large          sedan
# 6565              4.0  exotic,high-performance        large          sedan
# 6566              4.0       exotic,performance        large          sedan
# 6567              4.0       exotic,performance        large          sedan
# 6568              4.0       exotic,performance        large          sedan
# 6569              4.0  exotic,high-performance        large          sedan
# 6570              4.0  exotic,high-performance        large          sedan
# 6571              4.0       exotic,performance        large          sedan
# 7861              4.0                crossover      midsize        4dr_suv
# 7862              4.0                crossover      midsize        4dr_suv
# 9245              4.0                crossover      compact          wagon
# 9246              4.0                crossover      compact          wagon
# 9247              4.0                crossover      compact          wagon
# 9248              4.0                crossover      compact          wagon
# 9249              4.0                crossover      compact          wagon
# 9262              4.0                hatchback      compact  4dr_hatchback
# 9263              4.0                hatchback      compact  4dr_hatchback
# 9264              4.0                hatchback      compact  4dr_hatchback
# 9265              4.0                hatchback      compact  4dr_hatchback
# 9266              4.0                hatchback      compact  4dr_hatchback
# 9267              4.0                hatchback      compact  4dr_hatchback
#
#       highway_mpg  city_mpg  popularity    msrp
# 520           108       122         819   31800
# 521           103       121         819   31800
# 522           103       121         819   31800
# 1642           82        85         617   41450
# 1643           82        85         617   41450
# 1644           82        85         617   39900
# 4470          105       132        2202   36625
# 4471          105       132        2202   36625
# 4550           99       110        5657   29170
# 4554           99       110        5657   29170
# 4563           99       110        5657   29120
# 5505          111       137        3916   42400
# 5506          111       137        3916   42400
# 5507          111       137        3916   42400
# 5508          106       129        3916   43600
# 6035          101       126        2009   35020
# 6036          101       126        2009   32000
# 6037          101       126        2009   28980
# 6038          101       126        2009   32100
# 6039          101       126        2009   35120
# 6040          101       126        2009   29010
# 6041          101       126        2009   32000
# 6042          101       126        2009   29010
# 6043          101       124        2009   34200
# 6044          101       124        2009   36790
# 6554           90        88        1391   79900
# 6555           97        94        1391   69900
# 6556           94        86        1391  104500
# 6557           90        88        1391   93400
# 6558           97        94        1391   69900
# 6559          102       101        1391   75000
# 6560          106        95        1391   85000
# 6561           98        89        1391  105000
# 6562           90        88        1391   80000
# 6563          105       102        1391   79500
# 6564          101        98        1391   66000
# 6565          105        92        1391  134500
# 6566          100        97        1391   74500
# 6567          107       101        1391   71000
# 6568          102       101        1391   75000
# 6569          107       101        1391   89500
# 6570          100        91        1391  112000
# 6571           90        88        1391   70000
# 7861           74        78        2031   49800
# 7862           74        78        2031   49800
# 9245           92       120        1720   35700
# 9246           92       120        1720   33700
# 9247           92       120        1720   33950
# 9248           92       120        1720   31950
# 9249           92       120        1720   35950
# 9262          109       128        1385   26685
# 9263          109       128        1385   27010
# 9264          109       128        1385   25170
# 9265          109       128        1385   25560
# 9266          109       128        1385   25510
# 9267          109       128        1385   25120
#
#
# Records with 0 values in number_of_doors :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with 0 values in highway_mpg :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with 0 values in city_mpg :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with 0 values in popularity :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with 0 values in msrp :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []

# %%
# Checking Correlation between the variables

# %%
df.corr().style.background_gradient("copper_r")
# Out:
# <style type="text/css">
# #T_19421_row0_col0, #T_19421_row1_col1, #T_19421_row2_col2, #T_19421_row3_col3, #T_19421_row4_col4, #T_19421_row5_col5, #T_19421_row6_col6, #T_19421_row7_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_19421_row0_col1 {
#   background-color: #9a623e;
#   color: #f1f1f1;
# }
# #T_19421_row0_col2 {
#   background-color: #cc8152;
#   color: #f1f1f1;
# }
# #T_19421_row0_col3 {
#   background-color: #ce8253;
#   color: #f1f1f1;
# }
# #T_19421_row0_col4 {
#   background-color: #955f3c;
#   color: #f1f1f1;
# }
# #T_19421_row0_col5 {
#   background-color: #a46842;
#   color: #f1f1f1;
# }
# #T_19421_row0_col6, #T_19421_row1_col5 {
#   background-color: #ffad6e;
#   color: #000000;
# }
# #T_19421_row0_col7 {
#   background-color: #d68756;
#   color: #f1f1f1;
# }
# #T_19421_row1_col0 {
#   background-color: #cb8052;
#   color: #f1f1f1;
# }
# #T_19421_row1_col2 {
#   background-color: #2c1c12;
#   color: #f1f1f1;
# }
# #T_19421_row1_col3, #T_19421_row3_col7 {
#   background-color: #ffc47d;
#   color: #000000;
# }
# #T_19421_row1_col4 {
#   background-color: #ffaa6c;
#   color: #000000;
# }
# #T_19421_row1_col6 {
#   background-color: #ffb473;
#   color: #000000;
# }
# #T_19421_row1_col7 {
#   background-color: #5b3a25;
#   color: #f1f1f1;
# }
# #T_19421_row2_col0, #T_19421_row2_col3, #T_19421_row2_col4, #T_19421_row2_col5, #T_19421_row3_col6, #T_19421_row4_col1, #T_19421_row4_col2, #T_19421_row4_col7, #T_19421_row5_col7, #T_19421_row7_col3 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_19421_row2_col1 {
#   background-color: #342115;
#   color: #f1f1f1;
# }
# #T_19421_row2_col6 {
#   background-color: #ffb573;
#   color: #000000;
# }
# #T_19421_row2_col7 {
#   background-color: #7d4f32;
#   color: #f1f1f1;
# }
# #T_19421_row3_col0, #T_19421_row4_col0 {
#   background-color: #e6915d;
#   color: #f1f1f1;
# }
# #T_19421_row3_col1 {
#   background-color: #ffa669;
#   color: #000000;
# }
# #T_19421_row3_col2 {
#   background-color: #e3905c;
#   color: #f1f1f1;
# }
# #T_19421_row3_col4 {
#   background-color: #af6f47;
#   color: #f1f1f1;
# }
# #T_19421_row3_col5 {
#   background-color: #b27048;
#   color: #f1f1f1;
# }
# #T_19421_row4_col3 {
#   background-color: #f39a62;
#   color: #000000;
# }
# #T_19421_row4_col5, #T_19421_row5_col4 {
#   background-color: #160e09;
#   color: #f1f1f1;
# }
# #T_19421_row4_col6 {
#   background-color: #ffc07a;
#   color: #000000;
# }
# #T_19421_row5_col0 {
#   background-color: #f79c64;
#   color: #000000;
# }
# #T_19421_row5_col1, #T_19421_row7_col6 {
#   background-color: #ffc67e;
#   color: #000000;
# }
# #T_19421_row5_col2 {
#   background-color: #ffc37c;
#   color: #000000;
# }
# #T_19421_row5_col3, #T_19421_row7_col0 {
#   background-color: #f19861;
#   color: #000000;
# }
# #T_19421_row5_col6 {
#   background-color: #ffbd78;
#   color: #000000;
# }
# #T_19421_row6_col0 {
#   background-color: #ffb170;
#   color: #000000;
# }
# #T_19421_row6_col1 {
#   background-color: #de8d5a;
#   color: #f1f1f1;
# }
# #T_19421_row6_col2 {
#   background-color: #be784d;
#   color: #f1f1f1;
# }
# #T_19421_row6_col3 {
#   background-color: #ffb875;
#   color: #000000;
# }
# #T_19421_row6_col4, #T_19421_row6_col5 {
#   background-color: #c97f51;
#   color: #f1f1f1;
# }
# #T_19421_row6_col7 {
#   background-color: #ffb472;
#   color: #000000;
# }
# #T_19421_row7_col1 {
#   background-color: #4f3220;
#   color: #f1f1f1;
# }
# #T_19421_row7_col2 {
#   background-color: #5a3924;
#   color: #f1f1f1;
# }
# #T_19421_row7_col4 {
#   background-color: #e7925d;
#   color: #f1f1f1;
# }
# #T_19421_row7_col5 {
#   background-color: #eb945f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19421">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19421_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_19421_level0_col1" class="col_heading level0 col1" >engine_hp</th>
#       <th id="T_19421_level0_col2" class="col_heading level0 col2" >engine_cylinders</th>
#       <th id="T_19421_level0_col3" class="col_heading level0 col3" >number_of_doors</th>
#       <th id="T_19421_level0_col4" class="col_heading level0 col4" >highway_mpg</th>
#       <th id="T_19421_level0_col5" class="col_heading level0 col5" >city_mpg</th>
#       <th id="T_19421_level0_col6" class="col_heading level0 col6" >popularity</th>
#       <th id="T_19421_level0_col7" class="col_heading level0 col7" >msrp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19421_level0_row0" class="row_heading level0 row0" >year</th>
#       <td id="T_19421_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_19421_row0_col1" class="data row0 col1" >0.335125</td>
#       <td id="T_19421_row0_col2" class="data row0 col2" >-0.034288</td>
#       <td id="T_19421_row0_col3" class="data row0 col3" >0.245649</td>
#       <td id="T_19421_row0_col4" class="data row0 col4" >0.244613</td>
#       <td id="T_19421_row0_col5" class="data row0 col5" >0.188023</td>
#       <td id="T_19421_row0_col6" class="data row0 col6" >0.084830</td>
#       <td id="T_19421_row0_col7" class="data row0 col7" >0.208842</td>
#     </tr>
#     <tr>
#       <th id="T_19421_level0_row1" class="row_heading level0 row1" >engine_hp</th>
#       <td id="T_19421_row1_col0" class="data row1 col0" >0.335125</td>
#       <td id="T_19421_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_19421_row1_col2" class="data row1 col2" >0.772172</td>
#       <td id="T_19421_row1_col3" class="data row1 col3" >-0.129843</td>
#       <td id="T_19421_row1_col4" class="data row1 col4" >-0.359305</td>
#       <td id="T_19421_row1_col5" class="data row1 col5" >-0.350345</td>
#       <td id="T_19421_row1_col6" class="data row1 col6" >0.042029</td>
#       <td id="T_19421_row1_col7" class="data row1 col7" >0.658818</td>
#     </tr>
#     <tr>
#       <th id="T_19421_level0_row2" class="row_heading level0 row2" >engine_cylinders</th>
#       <td id="T_19421_row2_col0" class="data row2 col0" >-0.034288</td>
#       <td id="T_19421_row2_col1" class="data row2 col1" >0.772172</td>
#       <td id="T_19421_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_19421_row2_col3" class="data row2 col3" >-0.149708</td>
#       <td id="T_19421_row2_col4" class="data row2 col4" >-0.596376</td>
#       <td id="T_19421_row2_col5" class="data row2 col5" >-0.562677</td>
#       <td id="T_19421_row2_col6" class="data row2 col6" >0.038482</td>
#       <td id="T_19421_row2_col7" class="data row2 col7" >0.538883</td>
#     </tr>
#     <tr>
#       <th id="T_19421_level0_row3" class="row_heading level0 row3" >number_of_doors</th>
#       <td id="T_19421_row3_col0" class="data row3 col0" >0.245649</td>
#       <td id="T_19421_row3_col1" class="data row3 col1" >-0.129843</td>
#       <td id="T_19421_row3_col2" class="data row3 col2" >-0.149708</td>
#       <td id="T_19421_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_19421_row3_col4" class="data row3 col4" >0.114391</td>
#       <td id="T_19421_row3_col5" class="data row3 col5" >0.120469</td>
#       <td id="T_19421_row3_col6" class="data row3 col6" >-0.058326</td>
#       <td id="T_19421_row3_col7" class="data row3 col7" >-0.145564</td>
#     </tr>
#     <tr>
#       <th id="T_19421_level0_row4" class="row_heading level0 row4" >highway_mpg</th>
#       <td id="T_19421_row4_col0" class="data row4 col0" >0.244613</td>
#       <td id="T_19421_row4_col1" class="data row4 col1" >-0.359305</td>
#       <td id="T_19421_row4_col2" class="data row4 col2" >-0.596376</td>
#       <td id="T_19421_row4_col3" class="data row4 col3" >0.114391</td>
#       <td id="T_19421_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_19421_row4_col5" class="data row4 col5" >0.886288</td>
#       <td id="T_19421_row4_col6" class="data row4 col6" >-0.017423</td>
#       <td id="T_19421_row4_col7" class="data row4 col7" >-0.167008</td>
#     </tr>
#     <tr>
#       <th id="T_19421_level0_row5" class="row_heading level0 row5" >city_mpg</th>
#       <td id="T_19421_row5_col0" class="data row5 col0" >0.188023</td>
#       <td id="T_19421_row5_col1" class="data row5 col1" >-0.350345</td>
#       <td id="T_19421_row5_col2" class="data row5 col2" >-0.562677</td>
#       <td id="T_19421_row5_col3" class="data row5 col3" >0.120469</td>
#       <td id="T_19421_row5_col4" class="data row5 col4" >0.886288</td>
#       <td id="T_19421_row5_co

# %%
sns.heatmap(df.corr(),annot = True, lw = 0.1);

# %% [markdown]
# ## VISUALIZATIONS

# %% [markdown]
# ### Checking Relation between all variables

# %% [markdown]
# #### Distribution and relationship of Numerical Variables with dependent variable

# %%
numerical = [col for col in df.columns if col not in categorical]
for i in numerical:
   
    ax = sns.distplot(df[i], color = 'purple')
    plt.title("Distribution of %s" %i, fontsize = 20)
    plt.xlabel(" ")
    plt.ylabel(" ")
    plt.xticks(fontsize = 20)
    plt.show();
    print('\n')

# %%
sns.pairplot(df)

# %%
#scatterplot to understand the relationship between numerical variables and dependend variable MSRP
nrows = 2
ncols = 4
i = 0
fig, ax = plt.subplots(nrows, ncols, figsize = (16,8),)
for row in range(nrows):
    for col in range(ncols):
        sns.scatterplot(df[numerical].iloc[:, i],df['msrp'],ax = ax[row, col],color = 'maroon' ).set(ylabel = '')
        plt.tight_layout()
        i += 1

# %%
#Creating a function for ordering the groups in a column as per their frequency
def sort_order(column):
    orders = (df.groupby([column]).mean().sort_values(by ='msrp', ascending = False)).index
    return orders

# %%
#Looping over categorical variables to check the Price over different Groups
for i in categorical:
    if df[i].nunique() < 72:
        f,ax=plt.subplots(figsize=(20,10))
        sns.barplot(df[i],df['msrp'], order = sort_order(i), palette='coolwarm')
        plt.title("Bar Plot of %s" %i, fontsize = 20)
        plt.xticks(fontsize = 12)
        plt.xlabel("%s"%i)
        plt.ylabel("Car Price")
        plt.xticks(fontsize = 15, rotation = 90)
        plt.show();
        print('\n')

# %%
for i in categorical:
    if df[i].nunique() < 70:
        f,ax=plt.subplots(figsize=(10,5))
        df[i].value_counts().plot(kind='pie')
        plt.title("Pie Plot of %s" %i, fontsize = 20)
        plt.xticks(fontsize = 12)
        plt.xlabel("%s"%i)
        #plt.ylabel("Car Price")
        plt.xticks(fontsize = 15, rotation = 90)
        plt.show();
        print('\n')

# %%
 f,ax=plt.subplots(figsize=(10,8))
 sns.boxplot(x=df['transmission_type'],y=df['msrp'],hue=df['transmission_type'])
# Out:
# <AxesSubplot:xlabel='transmission_type', ylabel='msrp'>

# %%
counts=df['make'].value_counts()*100/sum(df['make'].value_counts())

# %%
import plotly.express as px

# %%
plt.rcParams['figure.figsize'] = (20,9)
x = pd.crosstab(df['make'],df['driven_wheels'])
x.div(x.sum(1).astype(float),axis = 0).plot(kind = 'bar',stacked = False)
plt.title('Make vs Drive Mode',fontweight = 30,fontsize = 20)
plt.show()

# %% [markdown]
# ## OUTLIER ANALYSIS AND REMOVAL

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
# Outlier Removal in Year

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.year,data=df)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
#OUTLIER DETECTION in CROP
#Function to calc lowerRange and UpperRange using 1.5IQR rule
def outlierDetection(data1):
    #Sort in Ascending
    sorted(data1)
    #Q1 and Q3
    Q1,Q3 = np.nanpercentile(data1, [25,75])
    #Calc IQR
    IQR = Q3 - Q1
    #Calc lowerRange
    lowerRange = Q1 - (1.5 * IQR)
    #Calc upperRange
    upperRange = Q3 + (1.5 * IQR)
    #Return Ranges
    return lowerRange,upperRange

# %%
lr,ur = outlierDetection(df.year)
lr,ur
# Out:
# (1993.5, 2029.5)

# %%
lr,ur=outlierDetection(df.year)
df.drop(df.index[(df.year > ur)],inplace=True)
df.drop(df.index[(df.year < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.year,data=df)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
lr,ur = outlierDetection(df.year)
lr,ur
# Out:
# (1996.0, 2028.0)

# %%
lr,ur=outlierDetection(df.year)
df.drop(df.index[(df.year > ur)],inplace=True)
df.drop(df.index[(df.year < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.year,data=df)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
lr,ur = outlierDetection(df.year)
lr,ur
# Out:
# (1998.5, 2026.5)

# %%
lr,ur=outlierDetection(df.year)
df.drop(df.index[(df.year > ur)],inplace=True)
df.drop(df.index[(df.year < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.year,data=df)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
lr,ur = outlierDetection(df.year)
lr,ur
# Out:
# (2001.0, 2025.0)

# %%
lr,ur=outlierDetection(df.year)
df.drop(df.index[(df.year > ur)],inplace=True)
df.drop(df.index[(df.year < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.year,data=df)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Outlier Removal in Engine HP

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.engine_hp,data=df)
# Out:
# <AxesSubplot:xlabel='engine_hp'>

# %%
lr,ur = outlierDetection(df.engine_hp)
lr,ur
# Out:
# (-10.0, 502.0)

# %%
lr,ur=outlierDetection(df.engine_hp)
df.drop(df.index[(df.engine_hp > ur)],inplace=True)
df.drop(df.index[(df.engine_hp < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.engine_hp,data=df)
# Out:
# <AxesSubplot:xlabel='engine_hp'>

# %%
lr,ur = outlierDetection(df.engine_hp)
lr,ur
# Out:
# (-3.0, 485.0)

# %%
lr,ur=outlierDetection(df.engine_hp)
df.drop(df.index[(df.engine_hp > ur)],inplace=True)
df.drop(df.index[(df.engine_hp < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.engine_hp,data=df)
# Out:
# <AxesSubplot:xlabel='engine_hp'>

# %%
# Outlier Removal in Engine Cylinders

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.engine_cylinders,data=df)
# Out:
# <AxesSubplot:xlabel='engine_cylinders'>

# %%
lr,ur = outlierDetection(df.engine_cylinders)
lr,ur
# Out:
# (1.0, 9.0)

# %%
lr,ur=outlierDetection(df.engine_cylinders)
df.drop(df.index[(df.engine_cylinders > ur)],inplace=True)
df.drop(df.index[(df.engine_cylinders < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.engine_cylinders,data=df)
# Out:
# <AxesSubplot:xlabel='engine_cylinders'>

# %%
# Outlier Removal in Highway MPG

# %%
ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.highway_mpg,data=df)
# Out:
# <AxesSubplot:xlabel='highway_mpg'>

# %%
lr,ur = outlierDetection(df.highway_mpg)
lr,ur
# Out:
# (11.0, 43.0)

# %%
lr,ur=outlierDetection(df.highway_mpg)
df.drop(df.index[(df.highway_mpg > ur)],inplace=True)
df.drop(df.index[(df.highway_mpg < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.highway_mpg,data=df)
# Out:
# <AxesSubplot:xlabel='highway_mpg'>

# %%
# Outlier Removal in City mpg

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.city_mpg,data=df)
# Out:
# <AxesSubplot:xlabel='city_mpg'>

# %%
lr,ur = outlierDetection(df.city_mpg)
lr,ur
# Out:
# (7.0, 31.0)

# %%
lr,ur=outlierDetection(df.city_mpg)
df.drop(df.index[(df.city_mpg > ur)],inplace=True)
df.drop(df.index[(df.city_mpg < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.city_mpg,data=df)
# Out:
# <AxesSubplot:xlabel='city_mpg'>

# %%
# Outlier Removal in Popularity

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.popularity,data=df)
# Out:
# <AxesSubplot:xlabel='popularity'>

# %%
lr,ur = outlierDetection(df.popularity)
lr,ur
# Out:
# (-1641.0, 4199.0)

# %%
lr,ur=outlierDetection(df.popularity)
df.drop(df.index[(df.popularity > ur)],inplace=True)
df.drop(df.index[(df.popularity < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.popularity,data=df)
# Out:
# <AxesSubplot:xlabel='popularity'>

# %%
lr,ur = outlierDetection(df.popularity)
lr,ur
# Out:
# (-1404.0, 3804.0)

# %%
lr,ur=outlierDetection(df.popularity)
df.drop(df.index[(df.popularity > ur)],inplace=True)
df.drop(df.index[(df.popularity < lr)],inplace=True)

# %%
f,ax=plt.subplots(figsize=(10,7))
sns.boxplot(df.popularity,data=df)
# Out:
# <AxesSubplot:xlabel='popularity'>

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,4,1)
sns.distplot(df['engine_hp'],color = 'blue')
plt.xlabel('Engine HP',fontsize = 12)
plt.grid()

plt.subplot(2,4,2)
sns.distplot(df['engine_cylinders'],color = 'green')
plt.xlabel('Engine Cylinders',fontsize = 12)
plt.grid()

plt.subplot(2,4,3)
sns.distplot(df['year'],color = 'darkblue')
plt.xlabel('Year',fontsize = 12)
plt.grid()

plt.subplot(2,4,4)
sns.distplot(df['highway_mpg'],color = 'black')
plt.xlabel('Highway MPG',fontsize = 12)
plt.grid()

plt.subplot(2,4,5)
sns.distplot(df['city_mpg'],color = 'grey')
plt.xlabel('City MPG',fontsize = 12)
plt.grid()

plt.subplot(2,4,6)
sns.distplot(df['popularity'],color = 'lightgreen')
plt.xlabel('Popularity',fontsize = 12)
plt.grid()

plt.suptitle('Distribution for Car Features', fontsize = 20)
plt.show()

# %%
# One Hot Encoding of the Categorical Columns

# %%
# label encoding all the categories data and getting final dataset
final=pd.get_dummies(df, columns=['transmission_type','driven_wheels','vehicle_size'])
final
# Out:
#            make       model  year                engine_fuel_type  engine_hp  \
# 27         fiat  124_spider  2017  premium_unleaded_(recommended)      160.0
# 28         fiat  124_spider  2017  premium_unleaded_(recommended)      160.0
# 29         fiat  124_spider  2017  premium_unleaded_(recommended)      160.0
# 59     chrysler         200  2015        flex-fuel_(unleaded/e85)      184.0
# 60     chrysler         200  2015        flex-fuel_(unleaded/e85)      184.0
# ...         ...         ...   ...                             ...        ...
# 11194     acura         zdx  2012     premium_unleaded_(required)      300.0
# 11195     acura         zdx  2012     premium_unleaded_(required)      300.0
# 11196     acura         zdx  2012     premium_unleaded_(required)      300.0
# 11197     acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11198   lincoln      zephyr  2006                regular_unleaded      221.0
#
#        engine_cylinders  number_of_doors             market_category  \
# 27                  4.0              2.0                 performance
# 28                  4.0              2.0                 performance
# 29                  4.0              2.0                 performance
# 59                  4.0              4.0                   flex_fuel
# 60                  4.0              4.0                   flex_fuel
# ...                 ...              ...                         ...
# 11194               6.0              4.0  crossover,hatchback,luxury
# 11195               6.0              4.0  crossover,hatchback,luxury
# 11196               6.0              4.0  crossover,hatchback,luxury
# 11197               6.0              4.0  crossover,hatchback,luxury
# 11198               6.0              4.0                      luxury
#
#        vehicle_style  highway_mpg  ...  transmission_type_automated_manual  \
# 27       convertible           35  ...                                   0
# 28       convertible           35  ...                                   0
# 29       convertible           35  ...                                   0
# 59             sedan           36  ...                                   0
# 60             sedan           36  ...                                   0
# ...              ...          ...  ...                                 ...
# 11194  4dr_hatchback           23  ...                                   0
# 11195  4dr_hatchback           23  ...                                   0
# 11196  4dr_hatchback           23  ...                                   0
# 11197  4dr_hatchback           23  ...                                   0
# 11198          sedan           26  ...                                   0
#
#        transmission_type_automatic  transmission_type_manual  \
# 27                               0                         1
# 28                               0                         1
# 29                               0                         1
# 59                               1                         0
# 60                               1                         0
# ...                            ...                       ...
# 11194                            1                         0
# 11195                            1                         0
# 11196                            1                         0
# 11197                            1                         0
# 11198                            1                         0
#
#        driven_wheels_all_wheel_drive  driven_wheels_four_wheel_drive  \
# 27                                 0                               0
# 28                                 0                               0
# 29                                 0                               0
# 59                                 0                               0
# 60                                 0                               0
# ...                              ...                             ...
# 11194                              1                               0
# 11195                              1                               0
# 11196                              1                               0
# 11197                              1                               0
# 11198                              0                               0
#
#        driven_wheels_front_wheel_drive  driven_wheels_rear_wheel_drive  \
# 27                                   0                               1
# 28                                   0                               1
# 29                                   0                               1
# 59                                   1                               0
# 60                                   1                               0
# ...                                ...                             ...
# 11194                                0                               0
# 11195                                0                               0
# 11196                                0                               0
# 11197                                0                               0
# 11198                                1                               0
#
#        vehicle_size_compact  vehicle_size_large  vehicle_size_midsize
# 27                        1                   0                     0
# 28                        1                   0                     0
# 29                        1                   0                     0
# 59                        0                   0                     1
# 60                        0                   0                     1
# ...                     ...                 ...                   ...
# 11194                     0                   0                     1
# 11195                     0                   0                     1
# 11196                     0                   0                     1
# 11197                     0                   0                     1
# 11198                     0                   0                     1
#
# [8044 rows x 23 columns]

# %%
sns.heatmap(final.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Car Price Prediction

# %%
# performing label encoding to the categorical columns
columns_to_convert=['make','model','engine_fuel_type','transmission_type','driven_wheels','vehicle_size','vehicle_style','market_category']
df[columns_to_convert] = df[columns_to_convert].astype('category')

# %%
df.dtypes
# Out:
# make                 category
# model                category
# year                    int64
# engine_fuel_type     category
# engine_hp             float64
# engine_cylinders      float64
# transmission_type    category
# driven_wheels        category
# number_of_doors       float64
# market_category      category
# vehicle_size         category
# vehicle_style        category
# highway_mpg             int64
# city_mpg                int64
# popularity              int64
# msrp                    int64
# dtype: object

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
for col in ['make','model','engine_fuel_type','transmission_type','driven_wheels','vehicle_size','vehicle_style','market_category']: df[col] = label_encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#     make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 27    11      0  2017                 6      160.0               4.0
# 28    11      0  2017                 6      160.0               4.0
# 29    11      0  2017                 6      160.0               4.0
# 59     8      2  2015                 3      184.0               4.0
# 60     8      2  2015                 3      184.0               4.0
#
#     transmission_type  driven_wheels  number_of_doors  market_category  \
# 27                  2              3              2.0               58
# 28                  2              3              2.0               58
# 29                  2              3              2.0               58
# 59                  1              2              4.0               34
# 60                  1              2              4.0               34
#
#     vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 27             0              6           35        26         819  27495
# 28             0              6           35        26         819  24995
# 29             0              6           35        26         819  28195
# 59             2             14           36        23        1013  25170
# 60             2             14           36        23        1013  23950

# %%
# splitting the dependent and independent variables

x = df[['popularity','year','engine_hp','engine_cylinders','highway_mpg']].values
y = df['msrp'].values

print(x.shape)
print(y.shape)
# Out:
# (8044, 5)
# (8044,)

# %%
#normalizing the data
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
sc_y=StandardScaler()

x=sc_x.fit_transform(x)
y=sc_y.fit_transform(y.reshape(-1,1))

# %%
# splitting the dataset into training and test sets

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (6435, 5)
# (6435, 1)
# (1609, 5)
# (1609, 1)

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(x_train,y_train)

# calculating the accuracies
print("Training Accuracy :",lr_model.score(x_train,y_train))
print("Testing Accuracy :",lr_model.score(x_test,y_test))
# Out:
# Training Accuracy : 0.5013922984990529
# Testing Accuracy : 0.46679542808295826

# %%
y_pred = lr_model.predict(x_test)
y_pred[0:5]
# Out:
# array([[-0.96410796],
#        [-0.15578318],
#        [-0.62857092],
#        [-0.81966507],
#        [-0.93292876]])

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
sns.distplot((y_test-y_pred),bins=50)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import math


print("Mean Squared Error : ", mean_squared_error(y_test,y_pred))
print("MAE : ",mean_absolute_error(y_test,y_pred))
print("RSME : ",math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean Squared Error :  0.5702440627096136
# MAE :  0.3801892965324984
# RSME :  0.7551450607066258

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVR
svr_model=SVR(kernel = 'rbf')
svr_model.fit(x_train,y_train)

# calculating the accuracies
print("Training Accuracy :",svr_model.score(x_train,y_train))
print("Testing Accuracy :",svr_model.score(x_test,y_test))
# Out:
# Training Accuracy : 0.7438828197255467
# Testing Accuracy : 0.6664878833308165

# %%
y_pred = svr_model.predict(x_test)
y_pred[0:5]
# Out:
# array([-0.65844942, -0.23991714, -0.48807363, -0.71237593, -0.94703644])

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
sns.distplot((y_test-y_pred),bins=50)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print("Mean Squared Error : ", mean_squared_error(y_test,y_pred))
print("MAE : ",mean_absolute_error(y_test,y_pred))
print("RSME : ",math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean Squared Error :  0.3566798080679386
# MAE :  0.26135147921289636
# RSME :  0.5972267643600198

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rfc_model=RandomForestRegressor(n_estimators=300,random_state=0)
rfc_model.fit(x_train,y_train)

# calculating the accuracies
print("Training Accuracy :",rfc_model.score(x_train,y_train))
print("Testing Accuracy :",rfc_model.score(x_test,y_test))
# Out:
# Training Accuracy : 0.972446476391551
# Testing Accuracy : 0.8546822021474453

# %%
y_pred = rfc_model.predict(x_test)
y_pred[0:5]
# Out:
# array([-0.641858  , -0.16429434, -0.39690468, -0.77962013, -0.93796156])

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
sns.distplot((y_test-y_pred),bins=50)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print("Mean Squared Error : ", mean_squared_error(y_test,y_pred))
print("MAE : ",mean_absolute_error(y_test,y_pred))
print("RSME : ",math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean Squared Error :  0.1554124172895275
# MAE :  0.15301499478979216
# RSME :  0.39422381623834896

# %%
# random forest gives the highest acuracy hence it is the best algorithm to predict Car Prices

# %% [markdown]
# ## Hyperparameter Tuning

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
 #Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   4.2s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   4.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   4.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   4.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   2.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   2.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   2.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   2.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   2.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=   3.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   3.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   3.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   5.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   3.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   3.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   2.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   2.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   2.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   2.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=   3.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   2.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   5.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   3.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   3.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   3.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=900; total time=   3.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   4.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.8s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   4.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   4.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   3.8s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   4.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   4.7s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   4.2s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   5.8s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   3.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   3.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   2.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   2.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   2.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   5.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   3.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   6.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   6.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   4.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   4.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   4.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   4.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=   4.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   1.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   1.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   1.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   1.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=   1.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.7s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.2s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   8.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   9.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   8.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   8.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   8.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   1.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   1.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   2.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   1.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   2.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   4.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   3.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   2.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   2.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   2.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   3.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   3.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   9.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   8.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   7.8s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=  11.4s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=   7.9s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   5.9s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   6.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   8.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   5.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   7.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   2.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   2.7s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   3.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   4.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   2.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=   2.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.9s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   2.0s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   2.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   2.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   3.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   2.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=   2.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   4.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   4.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   6.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   4.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=   4.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   3.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   6.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   5.6s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   6.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   6.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   5.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=700; total time=   2.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=700; total time=   2.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=700; total time=   2.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=700; total time=   2.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=700; total time=   2.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=200; total time=   0.8s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=200; total time=   0.8s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=200; total time=   1.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=200; total time=   1.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=200; total time=   1.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   1.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   1.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   3.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   3.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   3.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   2.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   2.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   4.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=100, n_estimators=900; total time=   2.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   0.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   0.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   1.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   1.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   1.6s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   1.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   1.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   1.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   4.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   1.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time=   3.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time=   5.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time=   3.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time=   3.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time=   3.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   6.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   6.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   7.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   8.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   2.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=1100; total time=   2.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   5.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   4.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   4.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   4.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   5.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   2.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   3.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   4.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   4.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   4.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   6.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   3.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   4.6s

# %%
rf_random.best_score_

# %%
predictions=rf_random.predict(x_test)

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)
